# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd

# %% [markdown]
# ## Lets go, Keras!

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation, InputLayer
from keras.layers.core import Dense, Flatten, Dropout

# %%
x_train = pd.read_csv("Athens_x_train.csv")
y_train = pd.read_csv("Athens_y_train.csv")

x_test = pd.read_csv("Athens_x_test.csv")
y_test = pd.read_csv("Athens_y_test.csv")

# %%
def drop_samevalue_columns(df):
    for col in range(len(df.columns)-1, -1, -1):
        row_list = []
        column_arr = df.iloc[:, col].to_list()
        for row in range(len(df)):
            row_list.append(column_arr[row])
        
        if len(set(row_list)) == 1:
            df.pop(df.columns[col])
    return

# %%
# drop columns which have only 1 value accross all rows
drop_samevalue_columns(x_train)
drop_samevalue_columns(x_test)

# apply normalization techniques
for column in x_train.columns:
	x_train[column] = (x_train[column] - x_train[column].mean()) / x_train[column].std()
	
for column in x_test.columns:
	x_test[column] = (x_test[column] - x_test[column].mean()) / x_test[column].std()

# %%
x_train
# Out:
#            N_cx    cx_0_1    cx_0_2    cx_0_3    cx_0_4    cx_1_0    cx_1_2  \
# 0     -0.083980  0.845916 -0.676863 -0.681556 -0.698119 -0.678601  0.835610
# 1     -0.083980  0.845916 -0.676863 -0.681556 -0.698119  2.354311  0.835610
# 2     -0.687137  0.845916 -0.676863 -0.681556 -0.698119  0.837855 -0.682108
# 3     -0.342475  0.845916  0.842848  0.854977  0.780893 -0.678601 -0.682108
# 4     -0.600971 -0.672293 -0.676863 -0.681556 -0.698119 -0.678601 -0.682108
# ...         ...       ...       ...       ...       ...       ...       ...
# 21401 -0.859467 -0.672293 -0.676863 -0.681556 -0.698119 -0.678601 -0.682108
# 21402  0.691508 -0.672293  0.842848  0.854977  2.259906  1.596083  0.076751
# 21403 -0.687137 -0.672293 -0.676863 -0.681556  0.780893 -0.678601 -0.682108
# 21404 -0.600971  0.086811 -0.676863 -0.681556 -0.698119  0.837855 -0.682108
# 21405 -0.687137 -0.672293  0.842848 -0.681556 -0.698119  0.837855  1.594469
#
#          cx_1_3    cx_1_4    cx_2_0  ...  readout_error_1      T1_2      T2_2  \
# 0      0.840605 -0.685110 -0.679708  ...         2.191481 -0.493675 -0.454840
# 1     -0.686509  0.074916  0.843436  ...        -0.243231 -2.394010 -2.027583
# 2     -0.686509 -0.685110 -0.679708  ...        -0.090395  0.994013  0.248109
# 3     -0.686509 -0.685110 -0.679708  ...        -0.342752  1.852855 -0.549416
# 4     -0.686509 -0.685110 -0.679708  ...        -0.165036  0.845608  0.521856
# ...         ...       ...       ...  ...              ...       ...       ...
# 21401  0.840605 -0.685110  0.081864  ...        -0.059591 -0.955807 -0.401426
# 21402  0.840605  0.834942 -0.679708  ...         0.204614  0.094344  0.230440
# 21403 -0.686509 -0.685110 -0.679708  ...        -0.271665  0.120190  0.800982
# 21404 -0.686509 -0.685110 -0.679708  ...        -0.271665  0.120190  0.800982
# 21405 -0.686509 -0.685110  0.843436  ...         0.204614  0.094344  0.230440
#
#        readout_error_2      T1_3      T2_3  readout_error_3      T1_4  \
# 0            -0.276212  0.283728 -0.390606        -0.145888 -0.708391
# 1             1.150873  1.339800 -0.312660        -0.523907  0.949129
# 2            -0.240937 -2.905421 -0.367970         1.471594 -1.864955
# 3            -0.376668  2.839530  0.008133        -0.343984 -1.280889
# 4            -0.243238  0.598689  2.173392        -0.158610 -0.124530
# ...                ...       ...       ...              ...       ...
# 21401        -0.199528 -0.940484 -0.831174        -0.418498  0.158788
# 21402        -0.351362 -1.001424 -0.335706        -0.409411  1.266196
# 21403        -0.194927  0.764986 -0.900382        -0.147706  0.054855
# 21404        -0.194927  0.764986 -0.900382        -0.147706  0.054855
# 21405        -0.351362 -1.001424 -0.335706        -0.409411  1.266196
#
#            T2_4  readout_error_4
# 0     -1.936209         0.136675
# 1      0.635158        -0.272392
# 2     -2.563778        -0.105046
# 3     -0.968885        -0.300283
# 4      0.171161        -0.170125
# ...         ...              ...
# 21401  0.627831        -0.173224
# 21402  1.054317        -0.225907
# 21403  1.272595        -0.210412
# 21404  1.272595        -0.210412
# 21405  1.054317        -0.225907
#
# [21406 rows x 52 columns]

# %% [markdown]
# ### Defining a one-hot-encoding function

# %%
def oneHotEncodeDF(df):
  for qbit in range(5):
    for oneHotValues in range(5):
      # We make a column for each of the 5 one_hot values, per qubit
      column = []
      for row in range(len(df)):
        if df[str(qbit)][row]==oneHotValues:
          column.append(1)
        else:
          column.append(0)

      # Add the column to the dataframe
      df[str(qbit)+"_"+str(oneHotValues)] = column

  # Droping the initial five columns
  df.drop(['0', '1', '2', '3', '4'], axis=1, inplace=True)

# %% [markdown]
# ### Defining a Repair Operator

# %%
# Input list has length 5x5 = 25

# This function uses the repair operator approach
def repair_operator(arr):
  assert len(arr)==25

  final_array = [-1, -1, -1, -1 ,-1]

  # Splitting the list
  q0 = arr[0:5]
  q1 = arr[5:10]
  q2 = arr[10:15]
  q3 = arr[15:20]
  q4 = arr[20:25]

  # List of lists
  original = [q0, q1, q2, q3, q4]
  list_partitions = [q0, q1, q2, q3, q4]

  # Each iteration in while decides an output qbit for one of the 5 input qbits
  while(len(list_partitions)!=0):
    maxim = -1
    for iter in list_partitions:
      maxim=max(maxim, max(iter))

    for given_list in list_partitions:
      if maxim == max(given_list):
        pos = given_list.index(maxim)
        final_array[original.index(given_list)] = pos

        # removing that list and the possibility of another list getting the same qubit index
        list_partitions.remove(given_list)
        for iter in list_partitions:
          iter[pos] = -1
        break

  return final_array

# %%
def get_final_outputs(output):
    ans = output.tolist()
    new = []
    for arr in ans:
        new.append(repair_operator(arr))
    return new

def get_accuracy(inp, labl):
    inputs = inp.values.tolist()
    labels = labl.values.tolist()
    correct = 0
    total = 0
    for i in range(len(inputs)):
        if inputs[i][0]==labels[i][0] and inputs[i][1]==labels[i][1] and inputs[i][2]==labels[i][2] and inputs[i][3]==labels[i][3] and inputs[i][4]==labels[i][4]:
            correct+=1
        total+=1
    acc = (correct*100)/total
    print("Total Predictions : ", total)
    print("Correct Predictions : ", correct)
    print("Accuracy : ", round(acc, 5))
    return

# %%
# Testing the repair operator
foo = [0.15, 0.23, 0.12 ,0.06, 0.4, 0.08, 0.16, 0.25, 0.13, 0.2, 0.05, 0.06, 0.31, 0.33, 0.2, 0.45, 0.1, 0.03, 0.15, 0.17, 0.27, 0.2, 0.18, 0.06, 0.18]
print(repair_operator(foo))
# output: [4, 2, 3, 0, 1]
# Out:
# [4, 2, 3, 0, 1]

# %% [markdown]
# ## Final NN

# %%
# Data elements have 78 features

# Output layer has 25 neurons (5x5)
# for each of the 5 circuit qbits, we have 5 probabilities corresponding to the 5 processor qbits
'''
nL0 = Sequential([
    Dense(264, input_shape=(52,), activation='relu'),
    Dense(1024, activation='relu'),
    Dropout(0.2),
    #Dense(1024, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')
])'''

nL0 = Sequential([
    Dense(256, input_shape=(52,), activation='relu'),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    Dropout(0.4),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')
])

nL1 = Sequential([
    Dense(50, input_shape=(52,), activation='relu'),
    Dropout(0.2),
    Dense(24, activation='relu'),
    Dense(5, activation='softmax')
])

nL2 = Sequential([
    Dense(264, input_shape=(52,), activation='relu'),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')
])

nL3 = Sequential([
    Dense(264, input_shape=(52,), activation='relu'),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')
])

nL4 = Sequential([
    Dense(264, input_shape=(52,), activation='relu'),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')
])

# %%
# One hot encoding the label vector and feeding the data into the neural network
training_labels = y_train.copy()

oneHotEncodeDF(training_labels)

# Five different training lables for the 5 different NNs on the same input dataset
train_0 = training_labels.iloc[:, 0:5]
train_1 = training_labels.iloc[:, 5:10]
train_2 = training_labels.iloc[:, 10:15]
train_3 = training_labels.iloc[:, 15:20]
train_4 = training_labels.iloc[:, 20:25]

# %%
# Compiling the neural Layouts
optim = keras.optimizers.Adam(learning_rate=0.03)

neuralLayouts = [nL0, nL1, nL2, nL3, nL4]
for nL in neuralLayouts:
    nL.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

nL0.summary()
# Out:
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_337 (Dense)           (None, 256)               13568
#
#  dense_338 (Dense)           (None, 512)               131584
#
#  dropout_106 (Dropout)       (None, 512)               0
#
#  dense_339 (Dense)           (None, 1024)              525312
#
#  dropout_107 (Dropout)       (None, 1024)              0
#
#  dense_340 (Dense)           (None, 256)               262400
#
#  dropout_108 (Dropout)       (None, 256)               0
#
#  dense_341 (Dense)           (None, 128)               32896
#
#  dense_342 (Dense)           (None, 5)                 645
#
# =================================================================
# Total params: 966,405
# Trainable params: 966,405
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Neural Net 0
nL0.fit(x_train, train_0, validation_split=0.2, batch_size=50, epochs=150, verbose=1)
# Out:
# Epoch 1/150
# 343/343 [==============================] - 3s 7ms/step - loss: 1.5257 - accuracy: 0.3525 - val_loss: 1.4992 - val_accuracy: 0.3557
# Epoch 2/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.5018 - accuracy: 0.3551 - val_loss: 1.5018 - val_accuracy: 0.3578
# Epoch 3/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4913 - accuracy: 0.3573 - val_loss: 1.5075 - val_accuracy: 0.3494
# Epoch 4/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4815 - accuracy: 0.3607 - val_loss: 1.4961 - val_accuracy: 0.3594
# Epoch 5/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4698 - accuracy: 0.3608 - val_loss: 1.5019 - val_accuracy: 0.3554
# Epoch 6/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4559 - accuracy: 0.3710 - val_loss: 1.4999 - val_accuracy: 0.3559
# Epoch 7/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4405 - accuracy: 0.3811 - val_loss: 1.5084 - val_accuracy: 0.3435
# Epoch 8/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4236 - accuracy: 0.3864 - val_loss: 1.5124 - val_accuracy: 0.3428
# Epoch 9/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4001 - accuracy: 0.4018 - val_loss: 1.5427 - val_accuracy: 0.3403
# Epoch 10/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.3744 - accuracy: 0.4123 - val_loss: 1.5463 - val_accuracy: 0.3477
# Epoch 11/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.3423 - accuracy: 0.4369 - val_loss: 1.5736 - val_accuracy: 0.3277
# Epoch 12/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.3026 - accuracy: 0.4533 - val_loss: 1.6420 - val_accuracy: 0.3298
# Epoch 13/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.2609 - accuracy: 0.4674 - val_loss: 1.6536 - val_accuracy: 0.3111
# Epoch 14/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.2121 - accuracy: 0.4946 - val_loss: 1.7162 - val_accuracy: 0.3027
# Epoch 15/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.1607 - accuracy: 0.5175 - val_loss: 1.7635 - val_accuracy: 0.2905
# Epoch 16/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.1106 - accuracy: 0.5409 - val_loss: 1.8336 - val_accuracy: 0.2922
# Epoch 17/150
# 343/343 [==============================] - 2s 6ms/step - loss: 1.0537 - accuracy: 0.5696 - val_loss: 1.9233 - val_accuracy: 0.3111
# Epoch 18/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9956 - accuracy: 0.5970 - val_loss: 2.0232 - val_accuracy: 0.3029
# Epoch 19/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9535 - accuracy: 0.6110 - val_loss: 2.0487 - val_accuracy: 0.2908
# Epoch 20/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8959 - accuracy: 0.6389 - val_loss: 2.1612 - val_accuracy: 0.3020
# Epoch 21/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8609 - accuracy: 0.6551 - val_loss: 2.2939 - val_accuracy: 0.2961
# Epoch 22/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8125 - accuracy: 0.6701 - val_loss: 2.3217 - val_accuracy: 0.2940
# Epoch 23/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7826 - accuracy: 0.6925 - val_loss: 2.3811 - val_accuracy: 0.2903
# Epoch 24/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7523 - accuracy: 0.7014 - val_loss: 2.4931 - val_accuracy: 0.2952
# Epoch 25/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7168 - accuracy: 0.7174 - val_loss: 2.5763 - val_accuracy: 0.2978
# Epoch 26/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6975 - accuracy: 0.7251 - val_loss: 2.5822 - val_accuracy: 0.3059
# Epoch 27/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6605 - accuracy: 0.7409 - val_loss: 2.6835 - val_accuracy: 0.2872
# Epoch 28/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6380 - accuracy: 0.7496 - val_loss: 2.7803 - val_accuracy: 0.2772
# Epoch 29/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6130 - accuracy: 0.7616 - val_loss: 2.7627 - val_accuracy: 0.2753
# Epoch 30/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5925 - accuracy: 0.7684 - val_loss: 2.9542 - val_accuracy: 0.2964
# Epoch 31/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5786 - accuracy: 0.7701 - val_loss: 3.0188 - val_accuracy: 0.2770
# Epoch 32/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5697 - accuracy: 0.7802 - val_loss: 2.9697 - val_accuracy: 0.2936
# Epoch 33/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5536 - accuracy: 0.7838 - val_loss: 3.0869 - val_accuracy: 0.2816
# Epoch 34/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5535 - accuracy: 0.7893 - val_loss: 2.9965 - val_accuracy: 0.2779
# Epoch 35/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5204 - accuracy: 0.7961 - val_loss: 3.1694 - val_accuracy: 0.2777
# Epoch 36/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5244 - accuracy: 0.7929 - val_loss: 3.0787 - val_accuracy: 0.2788
# Epoch 37/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5065 - accuracy: 0.8012 - val_loss: 3.1171 - val_accuracy: 0.2800
# Epoch 38/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4959 - accuracy: 0.8065 - val_loss: 3.1806 - val_accuracy: 0.2861
# Epoch 39/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4880 - accuracy: 0.8119 - val_loss: 3.3548 - val_accuracy: 0.2919
# Epoch 40/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4822 - accuracy: 0.8124 - val_loss: 3.2535 - val_accuracy: 0.2688
# Epoch 41/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4712 - accuracy: 0.8191 - val_loss: 3.2564 - val_accuracy: 0.2854
# Epoch 42/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4659 - accuracy: 0.8222 - val_loss: 3.2083 - val_accuracy: 0.2809
# Epoch 43/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4459 - accuracy: 0.8275 - val_loss: 3.4391 - val_accuracy: 0.2770
# Epoch 44/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4483 - accuracy: 0.8274 - val_loss: 3.3439 - val_accuracy: 0.2842
# Epoch 45/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4478 - accuracy: 0.8284 - val_loss: 3.3356 - val_accuracy: 0.2816
# Epoch 46/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4364 - accuracy: 0.8323 - val_loss: 3.3976 - val_accuracy: 0.2849
# Epoch 47/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4333 - accuracy: 0.8329 - val_loss: 3.4228 - val_accuracy: 0.2812
# Epoch 48/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4304 - accuracy: 0.8351 - val_loss: 3.3095 - val_accuracy: 0.2765
# Epoch 49/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4254 - accuracy: 0.8354 - val_loss: 3.4224 - val_accuracy: 0.2856
# Epoch 50/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4193 - accuracy: 0.8408 - val_loss: 3.2997 - val_accuracy: 0.2662
# Epoch 51/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4153 - accuracy: 0.8388 - val_loss: 3.3890 - val_accuracy: 0.2767
# Epoch 52/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4111 - accuracy: 0.8442 - val_loss: 3.5782 - val_accuracy: 0.2894
# Epoch 53/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4050 - accuracy: 0.8445 - val_loss: 3.4553 - val_accuracy: 0.2844
# Epoch 54/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.4021 - accuracy: 0.8451 - val_loss: 3.4508 - val_accuracy: 0.2812
# Epoch 55/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3908 - accuracy: 0.8516 - val_loss: 3.4728 - val_accuracy: 0.2835
# Epoch 56/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3849 - accuracy: 0.8525 - val_loss: 3.4671 - val_accuracy: 0.2858
# Epoch 57/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3905 - accuracy: 0.8482 - val_loss: 3.6322 - val_accuracy: 0.2723
# Epoch 58/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3842 - accuracy: 0.8539 - val_loss: 3.4874 - val_accuracy: 0.2779
# Epoch 59/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3822 - accuracy: 0.8505 - val_loss: 3.5408 - val_accuracy: 0.2908
# Epoch 60/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3819 - accuracy: 0.8530 - val_loss: 3.3734 - val_accuracy: 0.2908
# Epoch 61/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3631 - accuracy: 0.8599 - val_loss: 3.5696 - val_accuracy: 0.2767
# Epoch 62/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3625 - accuracy: 0.8615 - val_loss: 3.5775 - val_accuracy: 0.2784
# Epoch 63/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3705 - accuracy: 0.8600 - val_loss: 3.6049 - val_accuracy: 0.2819
# Epoch 64/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3537 - accuracy: 0.8666 - val_loss: 3.6154 - val_accuracy: 0.2795
# Epoch 65/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3706 - accuracy: 0.8575 - val_loss: 3.4433 - val_accuracy: 0.2704
# Epoch 66/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3629 - accuracy: 0.8613 - val_loss: 3.5172 - val_accuracy: 0.2910
# Epoch 67/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3565 - accuracy: 0.8625 - val_loss: 3.5982 - val_accuracy: 0.2879
# Epoch 68/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3619 - accuracy: 0.8625 - val_loss: 3.5988 - val_accuracy: 0.2919
# Epoch 69/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3519 - accuracy: 0.8657 - val_loss: 3.6438 - val_accuracy: 0.2805
# Epoch 70/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3433 - accuracy: 0.8683 - val_loss: 3.5967 - val_accuracy: 0.2807
# Epoch 71/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3371 - accuracy: 0.8706 - val_loss: 3.6532 - val_accuracy: 0.2865
# Epoch 72/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3309 - accuracy: 0.8734 - val_loss: 3.8278 - val_accuracy: 0.2842
# Epoch 73/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3515 - accuracy: 0.8650 - val_loss: 3.6298 - val_accuracy: 0.2854
# Epoch 74/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3347 - accuracy: 0.8723 - val_loss: 3.6056 - val_accuracy: 0.2840
# Epoch 75/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3345 - accuracy: 0.8750 - val_loss: 3.4400 - val_accuracy: 0.2833
# Epoch 76/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3396 - accuracy: 0.8721 - val_loss: 3.6927 - val_accuracy: 0.2919
# Epoch 77/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3380 - accuracy: 0.8718 - val_loss: 3.5534 - val_accuracy: 0.2872
# Epoch 78/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3276 - accuracy: 0.8751 - val_loss: 3.6701 - val_accuracy: 0.2828
# Epoch 79/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3367 - accuracy: 0.8713 - val_loss: 3.5386 - val_accuracy: 0.2809
# Epoch 80/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3184 - accuracy: 0.8784 - val_loss: 3.7746 - val_accuracy: 0.2919
# Epoch 81/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3232 - accuracy: 0.8751 - val_loss: 3.7152 - val_accuracy: 0.2863
# Epoch 82/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3150 - accuracy: 0.8777 - val_loss: 3.7445 - val_accuracy: 0.2915
# Epoch 83/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3179 - accuracy: 0.8779 - val_loss: 3.7744 - val_accuracy: 0.2851
# Epoch 84/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3144 - accuracy: 0.8796 - val_loss: 3.9260 - val_accuracy: 0.2884
# Epoch 85/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3161 - accuracy: 0.8793 - val_loss: 3.8565 - val_accuracy: 0.2833
# Epoch 86/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3198 - accuracy: 0.8777 - val_loss: 3.6352 - val_accuracy: 0.2795
# Epoch 87/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3113 - accuracy: 0.8827 - val_loss: 3.6997 - val_accuracy: 0.2919
# Epoch 88/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3080 - accuracy: 0.8850 - val_loss: 3.9246 - val_accuracy: 0.2777
# Epoch 89/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3105 - accuracy: 0.8797 - val_loss: 3.7185 - val_accuracy: 0.2837
# Epoch 90/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3064 - accuracy: 0.8833 - val_loss: 3.8248 - val_accuracy: 0.2903
# Epoch 91/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2984 - accuracy: 0.8862 - val_loss: 3.8611 - val_accuracy: 0.2952
# Epoch 92/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3012 - accuracy: 0.8868 - val_loss: 3.6168 - val_accuracy: 0.2891
# Epoch 93/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2985 - accuracy: 0.8851 - val_loss: 3.7625 - val_accuracy: 0.2840
# Epoch 94/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3053 - accuracy: 0.8827 - val_loss: 3.6077 - val_accuracy: 0.2908
# Epoch 95/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.3019 - accuracy: 0.8852 - val_loss: 3.7594 - val_accuracy: 0.2870
# Epoch 96/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2946 - accuracy: 0.8882 - val_loss: 3.7040 - val_accuracy: 0.2835
# Epoch 97/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2877 - accuracy: 0.8913 - val_loss: 3.9116 - val_accuracy: 0.2882
# Epoch 98/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2869 - accuracy: 0.8915 - val_loss: 3.8277 - val_accuracy: 0.2891
# Epoch 99/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2920 - accuracy: 0.8911 - val_loss: 3.6781 - val_accuracy: 0.2844
# Epoch 100/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2914 - accuracy: 0.8911 - val_loss: 3.7823 - val_accuracy: 0.2800
# Epoch 101/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2864 - accuracy: 0.8910 - val_loss: 3.8468 - val_accuracy: 0.2756
# Epoch 102/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2798 - accuracy: 0.8944 - val_loss: 3.9176 - val_accuracy: 0.2758
# Epoch 103/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2845 - accuracy: 0.8937 - val_loss: 3.9479 - val_accuracy: 0.2847
# Epoch 104/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2792 - accuracy: 0.8953 - val_loss: 3.9988 - val_accuracy: 0.2835
# Epoch 105/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2830 - accuracy: 0.8934 - val_loss: 3.8089 - val_accuracy: 0.2779
# Epoch 106/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2859 - accuracy: 0.8925 - val_loss: 3.5891 - val_accuracy: 0.2746
# Epoch 107/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2781 - accuracy: 0.8959 - val_loss: 3.7784 - val_accuracy: 0.2816
# Epoch 108/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2872 - accuracy: 0.8913 - val_loss: 3.6265 - val_accuracy: 0.2840
# Epoch 109/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2701 - accuracy: 0.8978 - val_loss: 3.6091 - val_accuracy: 0.2795
# Epoch 110/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2790 - accuracy: 0.8951 - val_loss: 3.8881 - val_accuracy: 0.2711
# Epoch 111/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2646 - accuracy: 0.8987 - val_loss: 3.8379 - val_accuracy: 0.2784
# Epoch 112/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2752 - accuracy: 0.8989 - val_loss: 4.1760 - val_accuracy: 0.2858
# Epoch 113/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2672 - accuracy: 0.8978 - val_loss: 3.9298 - val_accuracy: 0.2936
# Epoch 114/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2623 - accuracy: 0.8998 - val_loss: 3.9680 - val_accuracy: 0.2742
# Epoch 115/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2730 - accuracy: 0.8973 - val_loss: 3.7413 - val_accuracy: 0.2786
# Epoch 116/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2649 - accuracy: 0.8989 - val_loss: 3.7848 - val_accuracy: 0.2758
# Epoch 117/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2653 - accuracy: 0.8996 - val_loss: 3.8010 - val_accuracy: 0.2814
# Epoch 118/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2710 - accuracy: 0.9003 - val_loss: 3.7471 - val_accuracy: 0.2714
# Epoch 119/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2570 - accuracy: 0.9034 - val_loss: 4.0589 - val_accuracy: 0.2756
# Epoch 120/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2683 - accuracy: 0.8989 - val_loss: 3.8805 - val_accuracy: 0.2795
# Epoch 121/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2527 - accuracy: 0.9045 - val_loss: 4.0325 - val_accuracy: 0.2833
# Epoch 122/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2637 - accuracy: 0.9015 - val_loss: 3.7553 - val_accuracy: 0.2823
# Epoch 123/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2668 - accuracy: 0.9001 - val_loss: 3.8273 - val_accuracy: 0.2793
# Epoch 124/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2595 - accuracy: 0.9017 - val_loss: 3.7773 - val_accuracy: 0.2821
# Epoch 125/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2540 - accuracy: 0.9057 - val_loss: 4.0386 - val_accuracy: 0.2819
# Epoch 126/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2482 - accuracy: 0.9056 - val_loss: 4.1992 - val_accuracy: 0.2805
# Epoch 127/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2580 - accuracy: 0.9041 - val_loss: 3.9725 - val_accuracy: 0.2828
# Epoch 128/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2557 - accuracy: 0.9047 - val_loss: 3.9341 - val_accuracy: 0.2777
# Epoch 129/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2484 - accuracy: 0.9036 - val_loss: 3.8747 - val_accuracy: 0.2861
# Epoch 130/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2476 - accuracy: 0.9056 - val_loss: 3.9523 - val_accuracy: 0.2774
# Epoch 131/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2516 - accuracy: 0.9045 - val_loss: 3.8732 - val_accuracy: 0.2816
# Epoch 132/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2424 - accuracy: 0.9098 - val_loss: 3.9890 - val_accuracy: 0.2795
# Epoch 133/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2481 - accuracy: 0.9048 - val_loss: 3.8670 - val_accuracy: 0.2763
# Epoch 134/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2471 - accuracy: 0.9090 - val_loss: 3.9046 - val_accuracy: 0.2772
# Epoch 135/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2493 - accuracy: 0.9078 - val_loss: 3.9078 - val_accuracy: 0.2879
# Epoch 136/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2421 - accuracy: 0.9077 - val_loss: 3.9849 - val_accuracy: 0.2816
# Epoch 137/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2456 - accuracy: 0.9049 - val_loss: 3.7465 - val_accuracy: 0.2840
# Epoch 138/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2501 - accuracy: 0.9057 - val_loss: 3.7984 - val_accuracy: 0.2751
# Epoch 139/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2367 - accuracy: 0.9102 - val_loss: 4.0408 - val_accuracy: 0.2744
# Epoch 140/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2441 - accuracy: 0.9060 - val_loss: 3.9565 - val_accuracy: 0.2688
# Epoch 141/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2404 - accuracy: 0.9104 - val_loss: 3.9804 - val_accuracy: 0.2788
# Epoch 142/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2437 - accuracy: 0.9066 - val_loss: 3.9373 - val_accuracy: 0.2863
# Epoch 143/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2385 - accuracy: 0.9106 - val_loss: 4.1531 - val_accuracy: 0.2800
# Epoch 144/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2402 - accuracy: 0.9109 - val_loss: 4.0460 - val_accuracy: 0.2732
# Epoch 145/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2296 - accuracy: 0.9148 - val_loss: 4.1281 - val_accuracy: 0.2767
# Epoch 146/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2333 - accuracy: 0.9120 - val_loss: 4.2514 - val_accuracy: 0.2756
# Epoch 147/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2304 - accuracy: 0.9164 - val_loss: 4.2910 - val_accuracy: 0.2812
# Epoch 148/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2369 - accuracy: 0.9108 - val_loss: 3.8402 - val_accuracy: 0.2858
# Epoch 149/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2296 - accuracy: 0.9134 - val_loss: 4.1142 - val_accuracy: 0.2823
# Epoch 150/150
# 343/343 [==============================] - 2s 6ms/step - loss: 0.2293 - accuracy: 0.9143 - val_loss: 3.8534 - val_accuracy: 0.2856

# %%
# Neural Net 1
nL1.fit(x_train, train_1, validation_split=0.2, batch_size=50, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 343/343 [==============================] - 1s 1ms/step - loss: 1.5770 - accuracy: 0.3298 - val_loss: 1.5259 - val_accuracy: 0.3484
# Epoch 2/50
# 343/343 [==============================] - 0s 1ms/step - loss: 1.5190 - accuracy: 0.3610 - val_loss: 1.5167 - val_accuracy: 0.3533
# Epoch 3/50
# 343/343 [==============================] - 0s 1ms/step - loss: 1.5073 - accuracy: 0.3621 - val_loss: 1.5182 - val_accuracy: 0.3519
# Epoch 4/50
# 343/343 [==============================] - 0s 965us/step - loss: 1.5014 - accuracy: 0.3650 - val_loss: 1.5135 - val_accuracy: 0.3547
# Epoch 5/50
# 343/343 [==============================] - 0s 1ms/step - loss: 1.4962 - accuracy: 0.3667 - val_loss: 1.5129 - val_accuracy: 0.3550
# Epoch 6/50
# 343/343 [==============================] - 0s 975us/step - loss: 1.4923 - accuracy: 0.3682 - val_loss: 1.5107 - val_accuracy: 0.3573
# Epoch 7/50
# 343/343 [==============================] - 0s 970us/step - loss: 1.4876 - accuracy: 0.3712 - val_loss: 1.5117 - val_accuracy: 0.3536
# Epoch 8/50
# 343/343 [==============================] - 0s 960us/step - loss: 1.4852 - accuracy: 0.3684 - val_loss: 1.5066 - val_accuracy: 0.3580
# Epoch 9/50
# 343/343 [==============================] - 0s 963us/step - loss: 1.4801 - accuracy: 0.3735 - val_loss: 1.5078 - val_accuracy: 0.3538
# Epoch 10/50
# 343/343 [==============================] - 0s 980us/step - loss: 1.4791 - accuracy: 0.3718 - val_loss: 1.5052 - val_accuracy: 0.3620
# Epoch 11/50
# 343/343 [==============================] - 0s 975us/step - loss: 1.4764 - accuracy: 0.3733 - val_loss: 1.5079 - val_accuracy: 0.3624
# Epoch 12/50
# 343/343 [==============================] - 0s 983us/step - loss: 1.4723 - accuracy: 0.3752 - val_loss: 1.5070 - val_accuracy: 0.3561
# Epoch 13/50
# 343/343 [==============================] - 0s 998us/step - loss: 1.4681 - accuracy: 0.3761 - val_loss: 1.5035 - val_accuracy: 0.3606
# Epoch 14/50
# 343/343 [==============================] - 0s 986us/step - loss: 1.4682 - accuracy: 0.3770 - val_loss: 1.5012 - val_accuracy: 0.3589
# Epoch 15/50
# 343/343 [==============================] - 0s 960us/step - loss: 1.4627 - accuracy: 0.3768 - val_loss: 1.5005 - val_accuracy: 0.3638
# Epoch 16/50
# 343/343 [==============================] - 0s 1ms/step - loss: 1.4608 - accuracy: 0.3805 - val_loss: 1.4976 - val_accuracy: 0.3594
# Epoch 17/50
# 343/343 [==============================] - 0s 998us/step - loss: 1.4561 - accuracy: 0.3792 - val_loss: 1.4980 - val_accuracy: 0.3610
# Epoch 18/50
# 343/343 [==============================] - 0s 972us/step - loss: 1.4530 - accuracy: 0.3813 - val_loss: 1.4966 - val_accuracy: 0.3622
# Epoch 19/50
# 343/343 [==============================] - 0s 963us/step - loss: 1.4498 - accuracy: 0.3838 - val_loss: 1.4943 - val_accuracy: 0.3681
# Epoch 20/50
# 343/343 [==============================] - 0s 989us/step - loss: 1.4473 - accuracy: 0.3897 - val_loss: 1.4951 - val_accuracy: 0.3638
# Epoch 21/50
# 343/343 [==============================] - 0s 998us/step - loss: 1.4448 - accuracy: 0.3841 - val_loss: 1.4937 - val_accuracy: 0.3634
# Epoch 22/50
# 343/343 [==============================] - 0s 960us/step - loss: 1.4450 - accuracy: 0.3861 - val_loss: 1.4918 - val_accuracy: 0.3648
# Epoch 23/50
# 343/343 [==============================] - 0s 971us/step - loss: 1.4424 - accuracy: 0.3846 - val_loss: 1.4920 - val_accuracy: 0.3620
# Epoch 24/50
# 343/343 [==============================] - 0s 963us/step - loss: 1.4378 - accuracy: 0.3891 - val_loss: 1.4946 - val_accuracy: 0.3564
# Epoch 25/50
# 343/343 [==============================] - 0s 972us/step - loss: 1.4396 - accuracy: 0.3892 - val_loss: 1.4931 - val_accuracy: 0.3596
# Epoch 26/50
# 343/343 [==============================] - 0s 971us/step - loss: 1.4372 - accuracy: 0.3911 - val_loss: 1.4945 - val_accuracy: 0.3550
# Epoch 27/50
# 343/343 [==============================] - 0s 972us/step - loss: 1.4334 - accuracy: 0.3899 - val_loss: 1.4954 - val_accuracy: 0.3624
# Epoch 28/50
# 343/343 [==============================] - 0s 995us/step - loss: 1.4332 - accuracy: 0.3917 - val_loss: 1.4934 - val_accuracy: 0.3617
# Epoch 29/50
# 343/343 [==============================] - 0s 977us/step - loss: 1.4286 - accuracy: 0.3944 - val_loss: 1.4977 - val_accuracy: 0.3596
# Epoch 30/50
# 343/343 [==============================] - 0s 963us/step - loss: 1.4275 - accuracy: 0.3952 - val_loss: 1.4965 - val_accuracy: 0.3599
# Epoch 31/50
# 343/343 [==============================] - 0s 963us/step - loss: 1.4261 - accuracy: 0.3937 - val_loss: 1.4954 - val_accuracy: 0.3552
# Epoch 32/50
# 343/343 [==============================] - 0s 972us/step - loss: 1.4263 - accuracy: 0.3955 - val_loss: 1.4945 - val_accuracy: 0.3529
# Epoch 33/50
# 343/343 [==============================] - 0s 980us/step - loss: 1.4242 - accuracy: 0.3904 - val_loss: 1.4915 - val_accuracy: 0.3603
# Epoch 34/50
# 343/343 [==============================] - 0s 975us/step - loss: 1.4192 - accuracy: 0.3931 - val_loss: 1.4965 - val_accuracy: 0.3610
# Epoch 35/50
# 343/343 [==============================] - 0s 977us/step - loss: 1.4215 - accuracy: 0.3982 - val_loss: 1.4937 - val_accuracy: 0.3615
# Epoch 36/50
# 343/343 [==============================] - 0s 971us/step - loss: 1.4212 - accuracy: 0.3954 - val_loss: 1.4925 - val_accuracy: 0.3589
# Epoch 37/50
# 343/343 [==============================] - 0s 989us/step - loss: 1.4170 - accuracy: 0.3992 - val_loss: 1.4934 - val_accuracy: 0.3585
# Epoch 38/50
# 343/343 [==============================] - 0s 967us/step - loss: 1.4159 - accuracy: 0.3995 - val_loss: 1.4971 - val_accuracy: 0.3580
# Epoch 39/50
# 343/343 [==============================] - 0s 975us/step - loss: 1.4178 - accuracy: 0.3954 - val_loss: 1.4980 - val_accuracy: 0.3571
# Epoch 40/50
# 343/343 [==============================] - 0s 975us/step - loss: 1.4148 - accuracy: 0.4011 - val_loss: 1.4934 - val_accuracy: 0.3585
# Epoch 41/50
# 343/343 [==============================] - 0s 969us/step - loss: 1.4131 - accuracy: 0.3989 - val_loss: 1.4958 - val_accuracy: 0.3582
# Epoch 42/50
# 343/343 [==============================] - 0s 989us/step - loss: 1.4123 - accuracy: 0.3976 - val_loss: 1.4979 - val_accuracy: 0.3517
# Epoch 43/50
# 343/343 [==============================] - 0s 984us/step - loss: 1.4111 - accuracy: 0.4022 - val_loss: 1.4989 - val_accuracy: 0.3559
# Epoch 44/50
# 343/343 [==============================] - 0s 963us/step - loss: 1.4114 - accuracy: 0.4039 - val_loss: 1.4940 - val_accuracy: 0.3524
# Epoch 45/50
# 343/343 [==============================] - 0s 992us/step - loss: 1.4089 - accuracy: 0.4045 - val_loss: 1.4973 - val_accuracy: 0.3524
# Epoch 46/50
# 343/343 [==============================] - 0s 977us/step - loss: 1.4073 - accuracy: 0.3983 - val_loss: 1.4977 - val_accuracy: 0.3512
# Epoch 47/50
# 343/343 [==============================] - 0s 954us/step - loss: 1.4110 - accuracy: 0.4008 - val_loss: 1.4950 - val_accuracy: 0.3599
# Epoch 48/50
# 343/343 [==============================] - 0s 975us/step - loss: 1.4059 - accuracy: 0.4050 - val_loss: 1.4964 - val_accuracy: 0.3557
# Epoch 49/50
# 343/343 [==============================] - 0s 968us/step - loss: 1.4071 - accuracy: 0.4023 - val_loss: 1.4944 - val_accuracy: 0.3594
# Epoch 50/50
# 343/343 [==============================] - 0s 950us/step - loss: 1.3999 - accuracy: 0.4025 - val_loss: 1.4968 - val_accuracy: 0.3559

# %%
# Neural Net 2
nL2.fit(x_train, train_2, validation_split=0.2, batch_size=50, epochs=50, verbose=1)
# Out:
# Epoch 1/3
# 343/343 [==============================] - 3s 6ms/step - loss: 1.5066 - accuracy: 0.3662 - val_loss: 1.4911 - val_accuracy: 0.3657
# Epoch 2/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4840 - accuracy: 0.3690 - val_loss: 1.4759 - val_accuracy: 0.3660
# Epoch 3/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4724 - accuracy: 0.3715 - val_loss: 1.4789 - val_accuracy: 0.3641

# %%
# Neural Net 3
nL3.fit(x_train, train_3, validation_split=0.2, batch_size=50, epochs=50, verbose=1)
# Out:
# Epoch 1/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.5196 - accuracy: 0.3636 - val_loss: 1.5022 - val_accuracy: 0.3746
# Epoch 2/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4943 - accuracy: 0.3700 - val_loss: 1.4941 - val_accuracy: 0.3786
# Epoch 3/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4820 - accuracy: 0.3732 - val_loss: 1.4910 - val_accuracy: 0.3774

# %%
# Neural Net 4
nL4.fit(x_train, train_4, validation_split=0.2, batch_size=50, epochs=50, verbose=1)
# Out:
# Epoch 1/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.5332 - accuracy: 0.3506 - val_loss: 1.5121 - val_accuracy: 0.3610
# Epoch 2/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.5089 - accuracy: 0.3527 - val_loss: 1.5104 - val_accuracy: 0.3620
# Epoch 3/3
# 343/343 [==============================] - 2s 6ms/step - loss: 1.4959 - accuracy: 0.3595 - val_loss: 1.5101 - val_accuracy: 0.3557

# %%
# *****************************************************

# %%
pred0 = pd.DataFrame(nL0.predict(x_test))
pred1 = pd.DataFrame(nL1.predict(x_test))
pred2 = pd.DataFrame(nL2.predict(x_test))
pred3 = pd.DataFrame(nL3.predict(x_test))
pred4 = pd.DataFrame(nL4.predict(x_test))

prediction = pd.concat([pred0, pred1, pred2, pred3, pred4], axis=1, ignore_index=True)
# Out:
# 168/168 [==============================] - 0s 2ms/step
# 168/168 [==============================] - 0s 2ms/step
# 168/168 [==============================] - 0s 2ms/step
# 168/168 [==============================] - 0s 2ms/step
# 168/168 [==============================] - 0s 2ms/step

# %%
prediction
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.178387  0.135483  0.142969  0.162730  0.380432  0.158530  0.166376
# 1     0.196486  0.153939  0.183496  0.132668  0.333412  0.198270  0.178424
# 2     0.254425  0.108058  0.086498  0.137158  0.413860  0.137794  0.175203
# 3     0.190643  0.112256  0.101211  0.166487  0.429403  0.066421  0.114384
# 4     0.192511  0.110332  0.070600  0.111026  0.515532  0.131236  0.147182
# ...        ...       ...       ...       ...       ...       ...       ...
# 5347  0.309751  0.104564  0.228474  0.121599  0.235612  0.171495  0.158780
# 5348  0.251319  0.128285  0.194928  0.133331  0.292136  0.150738  0.190859
# 5349  0.238509  0.153411  0.128827  0.129718  0.349534  0.162426  0.117146
# 5350  0.190001  0.079601  0.050178  0.090924  0.589296  0.302786  0.165289
# 5351  0.065105  0.203934  0.237390  0.217189  0.276383  0.113054  0.225414
#
#             7         8         9   ...        15        16        17  \
# 0     0.150685  0.354266  0.170143  ...  0.115332  0.503176  0.124654
# 1     0.143764  0.355302  0.124240  ...  0.208036  0.316814  0.163580
# 2     0.156339  0.355791  0.174872  ...  0.160585  0.295321  0.204627
# 3     0.126271  0.604442  0.088482  ...  0.153760  0.432252  0.149663
# 4     0.048139  0.616097  0.057347  ...  0.054425  0.600482  0.101592
# ...        ...       ...       ...  ...       ...       ...       ...
# 5347  0.202566  0.284156  0.183003  ...  0.188426  0.264971  0.192032
# 5348  0.178783  0.310296  0.169324  ...  0.211249  0.267377  0.176681
# 5349  0.123308  0.394890  0.202231  ...  0.072482  0.460595  0.194271
# 5350  0.060266  0.411603  0.060056  ...  0.115014  0.425775  0.165499
# 5351  0.239183  0.167990  0.254358  ...  0.269760  0.142507  0.165618
#
#             18        19        20        21        22        23        24
# 0     0.152377  0.104460  0.300512  0.145695  0.144742  0.173618  0.235432
# 1     0.167383  0.144187  0.316975  0.159380  0.143385  0.160853  0.219407
# 2     0.181869  0.157599  0.282257  0.222028  0.165205  0.184543  0.145967
# 3     0.143000  0.121325  0.346149  0.234873  0.202446  0.156057  0.060475
# 4     0.156655  0.086847  0.669514  0.042522  0.050686  0.078401  0.158877
# ...        ...       ...       ...       ...       ...       ...       ...
# 5347  0.188334  0.166238  0.303657  0.169525  0.151793  0.155894  0.219131
# 5348  0.185719  0.158974  0.393012  0.202728  0.171122  0.153875  0.079263
# 5349  0.168914  0.103737  0.376773  0.134493  0.128579  0.156271  0.203885
# 5350  0.177542  0.116170  0.340479  0.163399  0.146455  0.176824  0.172843
# 5351  0.245062  0.177053  0.289740  0.243798  0.239709  0.169868  0.056886
#
# [5352 rows x 25 columns]

# %%
prediction = pd.DataFrame(get_final_outputs(np.array(prediction)))

# %%
prediction
# Out:
#       0  1  2  3  4
# 0     4  3  2  1  0
# 1     4  3  2  1  0
# 2     4  3  2  1  0
# 3     4  3  2  1  0
# 4     4  3  2  1  0
# ...  .. .. .. .. ..
# 5347  0  3  2  1  4
# 5348  4  3  2  1  0
# 5349  4  3  2  1  0
# 5350  4  3  2  1  0
# 5351  4  2  1  3  0
#
# [5352 rows x 5 columns]

# %%
y_test
# Out:
#         0    1    2    3    4
# 0     4.0  0.0  1.0  2.0  3.0
# 1     4.0  3.0  2.0  1.0  0.0
# 2     3.0  2.0  4.0  0.0  1.0
# 3     0.0  1.0  2.0  3.0  4.0
# 4     4.0  3.0  2.0  1.0  0.0
# ...   ...  ...  ...  ...  ...
# 5347  2.0  3.0  1.0  4.0  0.0
# 5348  4.0  1.0  0.0  3.0  2.0
# 5349  4.0  3.0  2.0  1.0  0.0
# 5350  4.0  3.0  2.0  1.0  0.0
# 5351  2.0  4.0  3.0  0.0  1.0
#
# [5352 rows x 5 columns]

# %%
get_accuracy(prediction, y_test)
# Out:
# Total Predictions :  5352
# Correct Predictions :  1075
# Accuracy :  20.08595

# %%
# *****************************************************
